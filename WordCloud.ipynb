# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Sample text
text = "LinkedIn,CareerConnect,JobHub,TalentNex,ProCareer,WorkLink,LinkedIn,EmployNet,LinkedIn,CareerForge,LinkedIn,EmployNet,SkillHaven,LinkedIn,JobAtlas,LinkedIn,JobAtlas,TalentSphere,WorkMagnet,ProfessioNet,SkillVista,LinkedIn,ProfessioNet,LinkedIn,LinkedIn,JobHub,JobHub,JobHub,JobHub,JobHub,JobHub,JobVortex,JobVortex,CareerPulseCareerSync,JobNestProOpportuneConnectCrafter,CareerHarbor,TalentForge,JobVista,WorkPulse,ProfessioLink,EmployCraft,CareerCraze,SkillSync,JobFor,WorkVibeProMagnet"

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(text)

# Display the generated word cloud using Matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
